# %%
# coding: utf-8
import numpy as np
import matplotlib.pylab as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_68513/3072621801.py in <module>
#       1 # coding: utf-8
#       2 import numpy as np
# ----> 3 import matplotlib.pylab as plt
#
# ~/.local/lib/python3.9/site-packages/matplotlib/__init__.py in <module>
#     105 # cbook must import matplotlib only within function
#     106 # definitions, so it is safe to import from it here.
# --> 107 from . import _api, cbook, docstring, rcsetup
#     108 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     109 from matplotlib.cbook import mplDeprecation  # deprecated
#
# ~/.local/lib/python3.9/site-packages/matplotlib/rcsetup.py in <module>
#      22 import numpy as np
#      23
# ---> 24 from matplotlib import _api, animation, cbook
#      25 from matplotlib.cbook import ls_mapper
#      26 from matplotlib.colors import Colormap, is_color_like
#
# ~/.local/lib/python3.9/site-packages/matplotlib/animation.py in <module>
#      32
#      33 import numpy as np
# ---> 34 from PIL import Image
#      35
#      36 import matplotlib as mpl
#
# ModuleNotFoundError: No module named 'PIL'

# %%
def numerical_diff(f, x):
    h = 1e-4 # 0.0001
    return (f(x+h) - f(x-h)) / (2*h)


def function_1(x):
    #return 0.01*x**2 + 0.1*x
    return x**2 + 1

def tangent_line(f, x):
    d = numerical_diff(f, x)
    print(d)
    y = f(x) - d*x
    return lambda t: d*t + y

# %%
x = np.arange(-1, 12.0, 0.1)
y = function_1(x)
plt.xlabel("x")
plt.ylabel("f(x)")

tf = tangent_line(function_1, 5)
y2 = tf(x)

plt.scatter(5, function_1(5))
plt.plot(x, y)
plt.plot(x, y2)
plt.grid()
plt.show()
# Out:
# 9.999999999976694

# %%
tf = tangent_line(function_1, 10)
y2 = tf(x)

plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y)
plt.plot(x, y2)
plt.scatter(10, function_1(10))
plt.grid()
plt.show()
# Out:
# 19.99999999995339

# %%
#tf = tangent_line(function_1, 10)
#
#def tangent_line(f, x):
#    d = numerical_diff(f, x)
#    print(d)
#    y = f(x) - d*x
#    return lambda t: d*t + y

d = numerical_diff(lambda x: x**2 + 1, 10)
intercept = (10**2 + 1) - d * 10
print(intercept)
y2 = d*x + intercept

#    return lambda t: d*t + y
plt.scatter(10, function_1(10))
plt.scatter(0, intercept)
plt.plot(x, y)
plt.plot(x, y2)
plt.grid()
plt.show()
# Out:
# -98.99999999953388
